# %%
#load in the data

import pandas as pd

df = pd.read_csv("french_corpora/Lexique383.tsv", sep="\t", encoding="utf-8")

# visualize the data
print(df.head())
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 #load in the data
# ----> 3 import pandas as pd
#       5 df = pd.read_csv("french_corpora/Lexique383.tsv", sep="\t", encoding="utf-8")
#       7 # visualize the data
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def build_markov_chain(data, order): 
    m_chain = 0
    return m_chain
