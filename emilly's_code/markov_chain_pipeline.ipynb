# %%
#load in the data

import pandas as pd
import os

# ! this dataset does not contain sentence data
data = pd.read_csv("/home/emilly/french_corpora/Lexique383.tsv", sep="\t", encoding="utf-8")

# visualize the data
#print(df.head())
print(df.columns)
# Out:
# Index(['ortho', 'phon', 'lemme', 'cgram', 'genre', 'nombre', 'freqlemfilms2',
#        'freqlemlivres', 'freqfilms2', 'freqlivres', 'infover', 'nbhomogr',
#        'nbhomoph', 'islem', 'nblettres', 'nbphons', 'cvcv', 'p_cvcv',
#        'voisorth', 'voisphon', 'puorth', 'puphon', 'syll', 'nbsyll', 'cv-cv',
#        'orthrenv', 'phonrenv', 'orthosyll', 'cgramortho', 'deflem', 'defobs',
#        'old20', 'pld20', 'morphoder', 'nbmorph'],
#       dtype='object')

# %%
# get the linguistic feature -> text to linguistic features pipeline 
data['syll'].head(80)
# Out:
# 0               a
# 1               a
# 2               a
# 3      a-ka-pE-la
# 4      a-ka-pE-la
#          ...
# 75    a-b@-do-nje
# 76    a-b@-do-nj§
# 77    a-b@-do-nik
# 78     a-b@-do-n§
# 79    a-b@-do-nam
# Name: syll, Length: 80, dtype: object

# %%
# tokenize the sentences in the right format: sents = [["sy1", "sy2", "sy3"], ["syA", "syB"], ...]

# %%
# generate an n-order markov chain

# input: tokenized syllable sequences
def build_markov_chain(data, k_max = 5): 
    for k in range(1, k_max):
        full_tokenized_sents = [['BOS'] * (k-1) + s +['EOS'] for s in sents]
        
        #frequency of all k-grams
        ngram_counts = defaultdict(int)
        for s in full_tokenized_sents:
            i in range(len(s)):
            if i in range(len(s) - )

    m_chain = 0
    return m_chain
