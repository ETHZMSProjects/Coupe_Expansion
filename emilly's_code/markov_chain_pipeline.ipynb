# %%
import pandas as pd
import os
import pickle
#import ipynb

# %%
import glob

folders = glob.glob(r"C:\Users\emill\Documents\GitHub\Coupe_Expansion\*")
print(folders)
# Out:
# []

# %%
import os

path = r"C:\Users\emill\Documents\GitHub\Coupe_Expansion"
print("Path exists:", os.path.exists(path))
print("Contents:", os.listdir(path) if os.path.exists(path) else "Path not found")
# Out:
# Path exists: False
# Contents: Path not found

# %%
import sys
import os

module_path = os.path.abspath(os.path.join(os.getcwd(), "emilly's_code"))
sys.path.append(module_path)

from syllabification import syllabify_sentences, tokenize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 7
#       4 module_path = os.path.abspath(os.path.join(os.getcwd(), "emilly's_code"))
#       5 sys.path.append(module_path)
# ----> 7 from syllabification import syllabify_sentences, tokenize
#
# ModuleNotFoundError: No module named 'syllabification'

# %%
sentence = "bonjour comment allez vous"
tok_sent = tokenize(sentence)
print(tok_sent)

syll_sent = syllabify_sentences(tok_sent)
print(syll_sent)
# Out:
# ['bonjour', 'comment', 'allez', 'vous']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 tok_sent = tokenize(sentence)
#       3 print(tok_sent)
# ----> 5 syll_sent = syllabify_sentences(tok_sent)
#       6 print(syll_sent)
#
# File c:\Users\emill\Documents\GitHub\Coupe_Expansion\emilly's_code\syllabification.py:43, in syllabify_sentences(tokenized_sentence, language, preview)
#      40 path = "french_lexique/Lexique383.tsv"
#      42 # Read the dataset into a DataFrame
# ---> 43 feature_df = pd.read_csv(path, sep="\t", encoding="utf-8")
#      45 # Drop rows with missing orthographic or syllable features
#      46 feature_df = feature_df.dropna(subset=['ortho', 'syll'])
#
# ...

# %%
# Read each line as a sentence
tokenized_sentences = []
transcribed_sentence = []

with open("french_sentences.txt", "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        sentence = line.strip()
        if sentence:
            # Tokenize
            tokenized_sentence = tokenize(sentence)
            tokenized_sentences.append(tokenized_sentence)
            
            # Syllabify
            transcribed_sentence = syllabify_sentences(tokenized_sentence, language="French")
            transcribed_sentences.append(transcribed_sentence)

        # Optional: limit for testing
            if i >= 10000:
             break

# Save to .pkl
with open("data/tokenized_sentences.pkl", "wb") as f:
    pickle.dump(tokenized_sentences, f)

with open("data/transcribed_sentences.pkl", "wb") as f:
    pickle.dump(transcribed_sentences, f)

print("✅ Saved tokenized and transcribed sentences for this language to 'data/'")

# %%
# generate an n-order markov chain

# input: tokenized syllable sequences
def build_markov_chain(data, k_max = 5): 
    for k in range(1, k_max):
        full_tokenized_sents = [['BOS'] * (k-1) + s +['EOS'] for s in sents]
        
        #frequency of all k-grams
        ngram_counts = defaultdict(int)
        for s in full_tokenized_sents:
            i in range(len(s)):
            if i in range(len(s) - )

    m_chain = 0
    return m_chain
